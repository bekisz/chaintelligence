# %%
import nasdaqdatalink
import pandas as pd

token = 'JEn6xy3nc1JtFSLoXoVJ'
wm2ns = nasdaqdatalink.get("FED/M2_N_WM", authtoken=token)    
df = pd.DataFrame(wm2ns)
df
# Out:
#               Value
# Date
# 1981-01-05   1620.7
# 1981-01-12   1616.7
# 1981-01-19   1614.4
# 1981-01-26   1599.8
# 1981-02-02   1601.0
# ...             ...
# 2023-04-03  20913.9
# 2023-04-10  21014.6
# 2023-04-17  20939.1
# 2023-04-24  20662.1
# 2023-05-01  20626.6
#
# [2209 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
